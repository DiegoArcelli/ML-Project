# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.models import Sequential
from keras.regularizers import l1, l2
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping
from scikeras.wrappers import KerasClassifier
from sklearn.model_selection import KFold
import keras_tuner
import keras
from keras import layers
import itertools
from keras.optimizers import SGD
import warnings
warnings.filterwarnings('ignore')

seed = 7
tf.random.set_seed(seed)

# %%
def load_monks(path):
    train = pd.read_csv(f"{path}.train", header=None, sep=" ")
    test = pd.read_csv(f"{path}.test", header=None, sep=" ")
    
    train.drop(0, axis=1, inplace=True)
    test.drop(0, axis=1, inplace=True)
    train.drop(8, axis=1, inplace=True)
    test.drop(8, axis=1, inplace=True)
    
    y_train = train.iloc[:, 0].to_numpy().astype(np.float64)
    x_train = train.iloc[:, 1:].to_numpy().astype(np.float64)
    y_test = test.iloc[:, 0].to_numpy().astype(np.float64)
    x_test = test.iloc[:, 1:].to_numpy().astype(np.float64)
    
    return x_train, y_train, x_test, y_test
    

def load_cup():
    train = pd.read_csv("../data/ML-CUP22-TR.csv", header=None, sep=",")
    test = pd.read_csv("../data/ML-CUP22-TS.csv", header=None, sep=",")
    train.drop(0, axis=1, inplace=True)
    test.drop(0, axis=1, inplace=True)
    train.head()
    y_train = train.iloc[:, :2].to_numpy().astype(np.float64)
    x_train = train.iloc[:, 2:].to_numpy().astype(np.float64)
    x_test = test.to_numpy().astype(np.float64)
    return x_train, y_train, x_test, None
    
def load_dataset(dataset):
    assert dataset in ["monks1", "monks2", "monks3", "cup"]
    
    if dataset == "monks1":
        return load_monks("./../data/monks-1")
    elif dataset == "monks2":
        return load_monks("./../data/monks-2")
    elif dataset == "monks3":
        return load_monks("./../data/monks-3")
    else:
        return load_cup()

# %%
params = {
    "learning_rate": [0.001, 0.01, 0.1, 0.2, 0.5],
    "batch_size": [8, 16, 32, 64],
    "momentum": [0.1, 0.2, 0.5, 0.9],
    "regularizer": [0.01, 0.1, 1],
    "layers": [
        {
            "activations": ["relu", "tanh"],
            "units": [1,2,3],
        },
        {
            "activations": ["relu", "tanh"],
            "units": [5,6],
        },
        {
            "activations": ["sigmoid"],
            "units": [3,7,15]
        }
    ]
}

k_fold_val = {
    "type": "k-fold",
    "n_folds": [2, 3, 5, 10, 15, 20]
}

hold_out_val = {
    "type": "hold-out",
    "val_split": 0.2
}


def merge_dicts(dicts):
    merged = {}
    for d in dicts:
        merged = {**merged, **d}
    return merged



def get_params_configurations(params):
    
    keys = list(params.keys())
    keys.remove("layers")
    sorted_keys = sorted(keys)
    print(sorted_keys)
    arguments = []
    for key in sorted_keys:
        arguments.append(params[key])
    
    arguments = tuple(arguments)
    all_params = list(itertools.product(*arguments))
    
    configurations = []
    
    for conf in all_params:
        
        dict_conf = {}
        
        for i in range(len(sorted_keys)):
            dict_conf[sorted_keys[i]] = conf[i]
        
        configurations.append(dict_conf)
        
    return configurations



def get_layers_configurations(params, configurations):
    layers = params["layers"]
    layers_params_confs = []
    
    for n_layer in range(len(layers)):
        layers_params_confs.append([]) 
    
    for i in range(len(layers)):
        layer = layers[i]
        activations = layer["activations"]
        units = layer["units"]
        layer_confs = list(itertools.product(activations, units))
        for conf in layer_confs:
            conf_dict = {
                f"activation_{i+1}": conf[0],
                f"unit_{i+1}": conf[1]
            }
            layers_params_confs[i].append(conf_dict)
        # layers_params_confs[i] = tuple(layers_params_confs[i])
        print(layers_params_confs[i])
        
    layers_confs = []
    for i in range(len(layers_params_confs)):
        print("\n\n")
        confs = layers_params_confs[:i+1]
        confs = tuple(confs)
        # confs = tuple(confs)
        confs = list(itertools.product(*confs))

        for conf in confs:
            print(merge_dicts(conf))
            
    return configurations



def get_configurations(params):
    configurations = get_params_configurations(params)
    configurations = get_layers_configurations(params, configurations)
    
    return configurations
    
    

def grid_search(params, validation=None):
    
    confs = get_configurations(params)
    print(confs[0])
    # search(confs)
    
    
    
    
        
        
        
grid_search(params)
# Out:
# ['batch_size', 'learning_rate', 'momentum', 'regularizer']
# [{'activation_1': 'relu', 'unit_1': 1}, {'activation_1': 'relu', 'unit_1': 2}, {'activation_1': 'relu', 'unit_1': 3}, {'activation_1': 'tanh', 'unit_1': 1}, {'activation_1': 'tanh', 'unit_1': 2}, {'activation_1': 'tanh', 'unit_1': 3}]
# [{'activation_2': 'relu', 'unit_2': 5}, {'activation_2': 'relu', 'unit_2': 6}, {'activation_2': 'tanh', 'unit_2': 5}, {'activation_2': 'tanh', 'unit_2': 6}]
# [{'activation_3': 'sigmoid', 'unit_3': 3}, {'activation_3': 'sigmoid', 'unit_3': 7}, {'activation_3': 'sigmoid', 'unit_3': 15}]
#
#
#
# {'activation_1': 'relu', 'unit_1': 1}
# {'activation_1': 'relu', 'unit_1': 2}
# {'activation_1': 'relu', 'unit_1': 3}
# {'activation_1': 'tanh', 'unit_1': 1}
# {'activation_1': 'tanh', 'unit_1': 2}
# {'activation_1': 'tanh', 'unit_1': 3}
#
#
#
# {'activation_1': 'relu', 'unit_1': 1, 'activation_2': 'relu', 'unit_2': 5}
# {'activation_1': 'relu', 'unit_1': 1, 'activation_2': 'relu', 'unit_2': 6}
# {'activation_1': 'relu', 'unit_1': 1, 'activation_2': 'tanh', 'unit_2': 5}
# {'activation_1': 'relu', 'unit_1': 1, 'activation_2': 'tanh', 'unit_2': 6}
# {'activation_1': 'relu', 'unit_1': 2, 'activation_2': 'relu', 'unit_2': 5}
# {'activation_1': 'relu', 'unit_1': 2, 'activation_2': 'relu', 'unit_2': 6}
# {'activation_1': 'relu', 'unit_1': 2, 'activation_2': 'tanh', 'unit_2': 5}
# {'activation_1': 'relu', 'unit_1': 2, 'activation_2': 'tanh', 'unit_2': 6}
# {'activation_1': 'relu', 'unit_1': 3, 'activation_2': 'relu', 'unit_2': 5}
# {'activation_1': 'relu', 'unit_1': 3, 'activation_2': 'relu', 'unit_2': 6}
# {'activation_1': 'relu', 'unit_1': 3, 'activation_2': 'tanh', 'unit_2': 5}
# {'activation_1': 'relu', 'unit_1': 3, 'activation_2': 'tanh', 'unit_2': 6}
# {'activation_1': 'tanh', 'unit_1': 1, 'activation_2': 'relu', 'unit_2': 5}
# {'activation_1': 'tanh', 'unit_1': 1, 'activation_2': 'relu', 'unit_2': 6}
# {'activation_1': 'tanh', 'unit_1': 1, 'activation_2': 'tanh', 'unit_2': 5}
# {'activation_1': 'tanh', 'unit_1': 1, 'activation_2': 'tanh', 'unit_2': 6}
# {'activation_1': 'tanh', 'unit_1': 2, 'activation_2': 'relu', 'unit_2': 5}
# {'activation_1': 'tanh', 'unit_1': 2, 'activation_2': 'relu', 'unit_2': 6}
# {'activation_1': 'tanh', 'unit_1': 2, 'activation_2': 'tanh', 'unit_2': 5}
# {'activation_1': 'tanh', 'unit_1': 2, 'activation_2': 'tanh', 'unit_2': 6}
# {'activation_1': 'tanh', 'unit_1': 3, 'activation_2': 'relu', 'unit_2': 5}
# {'activation_1': 'tanh', 'unit_1': 3, 'activation_2': 'relu', 'unit_2': 6}
# {'activation_1': 'tanh', 'unit_1': 3, 'activation_2': 'tanh', 'unit_2': 5}
# {'activation_1': 'tanh', 'unit_1': 3, 'activation_2': 'tanh', 'unit_2': 6}
#
#
#
# {'activation_1': 'relu', 'unit_1': 1, 'activation_2': 'relu', 'unit_2': 5, 'activation_3': 'sigmoid', 'unit_3': 3}
# {'activation_1': 'relu', 'unit_1': 1, 'activation_2': 'relu', 'unit_2': 5, 'activation_3': 'sigmoid', 'unit_3': 7}
# {'activation_1': 'relu', 'unit_1': 1, 'activation_2': 'relu', 'unit_2': 5, 'activation_3': 'sigmoid', 'unit_3': 15}
# {'activation_1': 'relu', 'unit_1': 1, 'activation_2': 'relu', 'unit_2': 6, 'activation_3': 'sigmoid', 'unit_3': 3}
# {'activation_1': 'relu', 'unit_1': 1, 'activation_2': 'relu', 'unit_2': 6, 'activation_3': 'sigmoid', 'unit_3': 7}
# {'activation_1': 'relu', 'unit_1': 1, 'activation_2': 'relu', 'unit_2': 6, 'activation_3': 'sigmoid', 'unit_3': 15}
# {'activation_1': 'relu', 'unit_1': 1, 'activation_2': 'tanh', 'unit_2': 5, 'activation_3': 'sigmoid', 'unit_3': 3}
# {'activation_1': 'relu', 'unit_1': 1, 'activation_2': 'tanh', 'unit_2': 5, 'activation_3': 'sigmoid', 'unit_3': 7}
# {'activation_1': 'relu', 'unit_1': 1, 'activation_2': 'tanh', 'unit_2': 5, 'activation_3': 'sigmoid', 'unit_3': 15}
# {'activation_1': 'relu', 'unit_1': 1, 'activation_2': 'tanh', 'unit_2': 6, 'activation_3': 'sigmoid', 'unit_3': 3}
# {'activation_1': 'relu', 'unit_1': 1, 'activation_2': 'tanh', 'unit_2': 6, 'activation_3': 'sigmoid', 'unit_3': 7}
# {'activation_1': 'relu', 'unit_1': 1, 'activation_2': 'tanh', 'unit_2': 6, 'activation_3': 'sigmoid', 'unit_3': 15}
# {'activation_1': 'relu', 'unit_1': 2, 'activation_2': 'relu', 'unit_2': 5, 'activation_3': 'sigmoid', 'unit_3': 3}
# {'activation_1': 'relu', 'unit_1': 2, 'activation_2': 'relu', 'unit_2': 5, 'activation_3': 'sigmoid', 'unit_3': 7}
# {'activation_1': 'relu', 'unit_1': 2, 'activation_2': 'relu', 'unit_2': 5, 'activation_3': 'sigmoid', 'unit_3': 15}
# {'activation_1': 'relu', 'unit_1': 2, 'activation_2': 'relu', 'unit_2': 6, 'activation_3': 'sigmoid', 'unit_3': 3}
# {'activation_1': 'relu', 'unit_1': 2, 'activation_2': 'relu', 'unit_2': 6, 'activation_3': 'sigmoid', 'unit_3': 7}
# {'activation_1': 'relu', 'unit_1': 2, 'activation_2': 'relu', 'unit_2': 6, 'activation_3': 'sigmoid', 'unit_3': 15}
# {'activation_1': 'relu', 'unit_1': 2, 'activation_2': 'tanh', 'unit_2': 5, 'activation_3': 'sigmoid', 'unit_3': 3}
# {'activation_1': 'relu', 'unit_1': 2, 'activation_2': 'tanh', 'unit_2': 5, 'activation_3': 'sigmoid', 'unit_3': 7}
# {'activation_1': 'relu', 'unit_1': 2, 'activation_2': 'tanh', 'unit_2': 5, 'activation_3': 'sigmoid', 'unit_3': 15}
# {'activation_1': 'relu', 'unit_1': 2, 'activation_2': 'tanh', 'unit_2': 6, 'activation_3': 'sigmoid', 'unit_3': 3}
# {'activation_1': 'relu', 'unit_1': 2, 'activation_2': 'tanh', 'unit_2': 6, 'activation_3': 'sigmoid', 'unit_3': 7}
# {'activation_1': 'relu', 'unit_1': 2, 'activation_2': 'tanh', 'unit_2': 6, 'activation_3': 'sigmoid', 'unit_3': 15}
# {'activation_1': 'relu', 'unit_1': 3, 'activation_2': 'relu', 'unit_2': 5, 'activation_3': 'sigmoid', 'unit_3': 3}
# {'activation_1': 'relu', 'unit_1': 3, 'activation_2': 'relu', 'unit_2': 5, 'activation_3': 'sigmoid', 'unit_3': 7}
# {'activation_1': 'relu', 'unit_1': 3, 'activation_2': 'relu', 'unit_2': 5, 'activation_3': 'sigmoid', 'unit_3': 15}
# {'activation_1': 'relu', 'unit_1': 3, 'activation_2': 'relu', 'unit_2': 6, 'activation_3': 'sigmoid', 'unit_3': 3}
# {'activation_1': 'relu', 'unit_1': 3, 'activation_2': 'relu', 'unit_2': 6, 'activation_3': 'sigmoid', 'unit_3': 7}
# {'activation_1': 'relu', 'unit_1': 3, 'activation_2': 'relu', 'unit_2': 6, 'activation_3': 'sigmoid', 'unit_3': 15}
# {'activation_1': 'relu', 'unit_1': 3, 'activation_2': 'tanh', 'unit_2': 5, 'activation_3': 'sigmoid', 'unit_3': 3}
# {'activation_1': 'relu', 'unit_1': 3, 'activation_2': 'tanh', 'unit_2': 5, 'activation_3': 'sigmoid', 'unit_3': 7}
# {'activation_1': 'relu', 'unit_1': 3, 'activation_2': 'tanh', 'unit_2': 5, 'activation_3': 'sigmoid', 'unit_3': 15}
# {'activation_1': 'relu', 'unit_1': 3, 'activation_2': 'tanh', 'unit_2': 6, 'activation_3': 'sigmoid', 'unit_3': 3}
# {'activation_1': 'relu', 'unit_1': 3, 'activation_2': 'tanh', 'unit_2': 6, 'activation_3': 'sigmoid', 'unit_3': 7}
# {'activation_1': 'relu', 'unit_1': 3, 'activation_2': 'tanh', 'unit_2': 6, 'activation_3': 'sigmoid', 'unit_3': 15}
# {'activation_1': 'tanh', 'unit_1': 1, 'activation_2': 'relu', 'unit_2': 5, 'activation_3': 'sigmoid', 'unit_3': 3}
# {'activation_1': 'tanh', 'unit_1': 1, 'activation_2': 'relu', 'unit_2': 5, 'activation_3': 'sigmoid', 'unit_3': 7}
# {'activation_1': 'tanh', 'unit_1': 1, 'activation_2': 'relu', 'unit_2': 5, 'activation_3': 'sigmoid', 'unit_3': 15}
# {'activation_1': 'tanh', 'unit_1': 1, 'activation_2': 'relu', 'unit_2': 6, 'activation_3': 'sigmoid', 'unit_3': 3}
# {'activation_1': 'tanh', 'unit_1': 1, 'activation_2': 'relu', 'unit_2': 6, 'activation_3': 'sigmoid', 'unit_3': 7}
# {'activation_1': 'tanh', 'unit_1': 1, 'activation_2': 'relu', 'unit_2': 6, 'activation_3': 'sigmoid', 'unit_3': 15}
# {'activation_1': 'tanh', 'unit_1': 1, 'activation_2': 'tanh', 'unit_2': 5, 'activation_3': 'sigmoid', 'unit_3': 3}
# {'activation_1': 'tanh', 'unit_1': 1, 'activation_2': 'tanh', 'unit_2': 5, 'activation_3': 'sigmoid', 'unit_3': 7}
# {'activation_1': 'tanh', 'unit_1': 1, 'activation_2': 'tanh', 'unit_2': 5, 'activation_3': 'sigmoid', 'unit_3': 15}
# {'activation_1': 'tanh', 'unit_1': 1, 'activation_2': 'tanh', 'unit_2': 6, 'activation_3': 'sigmoid', 'unit_3': 3}
# {'activation_1': 'tanh', 'unit_1': 1, 'activation_2': 'tanh', 'unit_2': 6, 'activation_3': 'sigmoid', 'unit_3': 7}
# {'activation_1': 'tanh', 'unit_1': 1, 'activation_2': 'tanh', 'unit_2': 6, 'activation_3': 'sigmoid', 'unit_3': 15}
# {'activation_1': 'tanh', 'unit_1': 2, 'activation_2': 'relu', 'unit_2': 5, 'activation_3': 'sigmoid', 'unit_3': 3}
# {'activation_1': 'tanh', 'unit_1': 2, 'activation_2': 'relu', 'unit_2': 5, 'activation_3': 'sigmoid', 'unit_3': 7}
# {'activation_1': 'tanh', 'unit_1': 2, 'activation_2': 'relu', 'unit_2': 5, 'activation_3': 'sigmoid', 'unit_3': 15}
# {'activation_1': 'tanh', 'unit_1': 2, 'activation_2': 'relu', 'unit_2': 6, 'activation_3': 'sigmoid', 'unit_3': 3}
# {'activation_1': 'tanh', 'unit_1': 2, 'activation_2': 'relu', 'unit_2': 6, 'activation_3': 'sigmoid', 'unit_3': 7}
# {'activation_1': 'tanh', 'unit_1': 2, 'activation_2': 'relu', 'unit_2': 6, 'activation_3': 'sigmoid', 'unit_3': 15}
# {'activation_1': 'tanh', 'unit_1': 2, 'activation_2': 'tanh', 'unit_2': 5, 'activation_3': 'sigmoid', 'unit_3': 3}
# {'activation_1': 'tanh', 'unit_1': 2, 'activation_2': 'tanh', 'unit_2': 5, 'activation_3': 'sigmoid', 'unit_3': 7}
# {'activation_1': 'tanh', 'unit_1': 2, 'activation_2': 'tanh', 'unit_2': 5, 'activation_3': 'sigmoid', 'unit_3': 15}
# {'activation_1': 'tanh', 'unit_1': 2, 'activation_2': 'tanh', 'unit_2': 6, 'activation_3': 'sigmoid', 'unit_3': 3}
# {'activation_1': 'tanh', 'unit_1': 2, 'activation_2': 'tanh', 'unit_2': 6, 'activation_3': 'sigmoid', 'unit_3': 7}
# {'activation_1': 'tanh', 'unit_1': 2, 'activation_2': 'tanh', 'unit_2': 6, 'activation_3': 'sigmoid', 'unit_3': 15}
# {'activation_1': 'tanh', 'unit_1': 3, 'activation_2': 'relu', 'unit_2': 5, 'activation_3': 'sigmoid', 'unit_3': 3}
# {'activation_1': 'tanh', 'unit_1': 3, 'activation_2': 'relu', 'unit_2': 5, 'activation_3': 'sigmoid', 'unit_3': 7}
# {'activation_1': 'tanh', 'unit_1': 3, 'activation_2': 'relu', 'unit_2': 5, 'activation_3': 'sigmoid', 'unit_3': 15}
# {'activation_1': 'tanh', 'unit_1': 3, 'activation_2': 'relu', 'unit_2': 6, 'activation_3': 'sigmoid', 'unit_3': 3}
# {'activation_1': 'tanh', 'unit_1': 3, 'activation_2': 'relu', 'unit_2': 6, 'activation_3': 'sigmoid', 'unit_3': 7}
# {'activation_1': 'tanh', 'unit_1': 3, 'activation_2': 'relu', 'unit_2': 6, 'activation_3': 'sigmoid', 'unit_3': 15}
# {'activation_1': 'tanh', 'unit_1': 3, 'activation_2': 'tanh', 'unit_2': 5, 'activation_3': 'sigmoid', 'unit_3': 3}
# {'activation_1': 'tanh', 'unit_1': 3, 'activation_2': 'tanh', 'unit_2': 5, 'activation_3': 'sigmoid', 'unit_3': 7}
# {'activation_1': 'tanh', 'unit_1': 3, 'activation_2': 'tanh', 'unit_2': 5, 'activation_3': 'sigmoid', 'unit_3': 15}
# {'activation_1': 'tanh', 'unit_1': 3, 'activation_2': 'tanh', 'unit_2': 6, 'activation_3': 'sigmoid', 'unit_3': 3}
# {'activation_1': 'tanh', 'unit_1': 3, 'activation_2': 'tanh', 'unit_2': 6, 'activation_3': 'sigmoid', 'unit_3': 7}
# {'activation_1': 'tanh', 'unit_1': 3, 'activation_2': 'tanh', 'unit_2': 6, 'activation_3': 'sigmoid', 'unit_3': 15}
# {'batch_size': 8, 'learning_rate': 0.001, 'momentum': 0.1, 'regularizer': 0.01}

# %%
x_train, y_train, x_test, y_test = load_dataset("monks1")
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (124, 6) (124,)
# (432, 6) (432,)

# %%
def build_model():
    model = Sequential()
    model.add(Dense(8, input_dim=6, activation="relu"))
    model.add(Dense(1, activation="sigmoid"))
    optimizer = SGD(learning_rate=0.1, momentum=0.9)
    model.compile(optimizer = optimizer, loss = 'mse', metrics = ['accuracy'])
    return model

# %%
# create model
model = KerasClassifier(model=build_model, verbose=0)

batch_size = [10, 20, 40, 60]
epochs = [300]

param_grid = dict(batch_size=batch_size, epochs=epochs)
grid = GridSearchCV(estimator=model, param_grid=param_grid, cv=2, n_jobs=-1, verbose=4)

grid_result = grid.fit(x_train, y_train)
# summarize results


print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Fitting 2 folds for each of 4 candidates, totalling 8 fits
# /home/diego/Desktop/Universita/Magistrale/FirstYear/ML/ML-Project/env/lib/python3.10/site-packages/keras/optimizers/optimizer_v2/gradient_descent.py:111: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# /home/diego/Desktop/Universita/Magistrale/FirstYear/ML/ML-Project/env/lib/python3.10/site-packages/keras/optimizers/optimizer_v2/gradient_descent.py:111: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# /home/diego/Desktop/Universita/Magistrale/FirstYear/ML/ML-Project/env/lib/python3.10/site-packages/keras/optimizers/optimizer_v2/gradient_descent.py:111: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# /home/diego/Desktop/Universita/Magistrale/FirstYear/ML/ML-Project/env/lib/python3.10/site-packages/keras/optimizers/optimizer_v2/gradient_descent.py:111: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# /home/diego/Desktop/Universita/Magistrale/FirstYear/ML/ML-Project/env/lib/python3.10/site-packages/keras/optimizers/optimizer_v2/gradient_descent.py:111: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# /home/diego/Desktop/Universita/Magistrale/FirstYear/ML/ML-Project/env/lib/python3.10/site-packages/keras/optimizers/optimizer_v2/gradient_descent.py:111: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# /home/diego/Desktop/Universita/Magistrale/FirstYear/ML/ML-Project/env/lib/python3.10/site-packages/keras/optimizers/optimizer_v2/gradient_descent.py:111: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# /home/diego/Desktop/Universita/Magistrale/FirstYear/ML/ML-Project/env/lib/python3.10/site-packages/keras/optimizers/optimizer_v2/gradient_descent.py:111: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Best: 0.580645 using {'batch_size': 60, 'epochs': 300}
# 0.524194 (0.024194) with: {'batch_size': 10, 'epochs': 300}
# 0.556452 (0.024194) with: {'batch_size': 20, 'epochs': 300}
# 0.500000 (0.000000) with: {'batch_size': 40, 'epochs': 300}
# 0.580645 (0.064516) with: {'batch_size': 60, 'epochs': 300}

# %%
model = build_model()
model.fit(x_train, y_train, epochs=300, batch_size=10)
# Out:
# Epoch 1/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2498 - accuracy: 0.5323
# Epoch 2/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2209 - accuracy: 0.6613
# Epoch 3/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2105 - accuracy: 0.6935
# Epoch 4/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2122 - accuracy: 0.6694
# Epoch 5/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2248 - accuracy: 0.6613
# Epoch 6/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2108 - accuracy: 0.6532
# Epoch 7/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2156 - accuracy: 0.6855
# Epoch 8/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2047 - accuracy: 0.7258
# Epoch 9/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1890 - accuracy: 0.7258
# Epoch 10/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1863 - accuracy: 0.7177
# Epoch 11/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1877 - accuracy: 0.7419
# Epoch 12/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1819 - accuracy: 0.7097
# Epoch 13/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1927 - accuracy: 0.7500
# Epoch 14/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1784 - accuracy: 0.7016
# Epoch 15/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1829 - accuracy: 0.7177
# Epoch 16/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1733 - accuracy: 0.7258
# Epoch 17/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1676 - accuracy: 0.7500
# Epoch 18/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1632 - accuracy: 0.7823
# Epoch 19/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1724 - accuracy: 0.7419
# Epoch 20/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1773 - accuracy: 0.6935
# Epoch 21/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1716 - accuracy: 0.7177
# Epoch 22/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1732 - accuracy: 0.7500
# Epoch 23/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1756 - accuracy: 0.7661
# Epoch 24/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1499 - accuracy: 0.7823
# Epoch 25/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1530 - accuracy: 0.7581
# Epoch 26/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1381 - accuracy: 0.7823
# Epoch 27/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1585 - accuracy: 0.7419
# Epoch 28/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1408 - accuracy: 0.7661
# Epoch 29/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1453 - accuracy: 0.7661
# Epoch 30/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1305 - accuracy: 0.7984
# Epoch 31/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1313 - accuracy: 0.7742
# Epoch 32/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1431 - accuracy: 0.7419
# Epoch 33/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1189 - accuracy: 0.7903
# Epoch 34/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1325 - accuracy: 0.7742
# Epoch 35/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1365 - accuracy: 0.7903
# Epoch 36/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1367 - accuracy: 0.7823
# Epoch 37/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1300 - accuracy: 0.7581
# Epoch 38/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1183 - accuracy: 0.7903
# Epoch 39/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1166 - accuracy: 0.7823
# Epoch 40/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1203 - accuracy: 0.7258
# Epoch 41/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1151 - accuracy: 0.7581
# Epoch 42/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1186 - accuracy: 0.7581
# Epoch 43/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1155 - accuracy: 0.7661
# Epoch 44/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1190 - accuracy: 0.7903
# Epoch 45/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1173 - accuracy: 0.7419
# Epoch 46/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1203 - accuracy: 0.7903
# Epoch 47/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1174 - accuracy: 0.7742
# Epoch 48/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1192 - accuracy: 0.7661
# Epoch 49/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1157 - accuracy: 0.7903
# Epoch 50/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1148 - accuracy: 0.7823
# Epoch 51/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1207 - accuracy: 0.7984
# Epoch 52/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1166 - accuracy: 0.7742
# Epoch 53/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1129 - accuracy: 0.7661
# Epoch 54/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1133 - accuracy: 0.7903
# Epoch 55/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1176 - accuracy: 0.7742
# Epoch 56/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1094 - accuracy: 0.7823
# Epoch 57/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1086 - accuracy: 0.7984
# Epoch 58/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1098 - accuracy: 0.7984
# Epoch 59/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1106 - accuracy: 0.7581
# Epoch 60/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1056 - accuracy: 0.8065
# Epoch 61/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1119 - accuracy: 0.7823
# Epoch 62/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1108 - accuracy: 0.7419
# Epoch 63/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1086 - accuracy: 0.7903
# Epoch 64/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1196 - accuracy: 0.7742
# Epoch 65/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1137 - accuracy: 0.7823
# Epoch 66/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1087 - accuracy: 0.7984
# Epoch 67/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1120 - accuracy: 0.7903
# Epoch 68/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1130 - accuracy: 0.7984
# Epoch 69/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1186 - accuracy: 0.7823
# Epoch 70/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1122 - accuracy: 0.7903
# Epoch 71/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1081 - accuracy: 0.8065
# Epoch 72/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1106 - accuracy: 0.7903
# Epoch 73/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1212 - accuracy: 0.7500
# Epoch 74/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1135 - accuracy: 0.7823
# Epoch 75/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1147 - accuracy: 0.8065
# Epoch 76/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1087 - accuracy: 0.7984
# Epoch 77/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1117 - accuracy: 0.7903
# Epoch 78/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1095 - accuracy: 0.7903
# Epoch 79/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1152 - accuracy: 0.7903
# Epoch 80/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1086 - accuracy: 0.7984
# Epoch 81/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1154 - accuracy: 0.7903
# Epoch 82/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1137 - accuracy: 0.7661
# Epoch 83/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1114 - accuracy: 0.7581
# Epoch 84/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1102 - accuracy: 0.7984
# Epoch 85/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1103 - accuracy: 0.7500
# Epoch 86/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1109 - accuracy: 0.7903
# Epoch 87/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1156 - accuracy: 0.7742
# Epoch 88/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1093 - accuracy: 0.7581
# Epoch 89/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1095 - accuracy: 0.7823
# Epoch 90/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1098 - accuracy: 0.7661
# Epoch 91/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1139 - accuracy: 0.7903
# Epoch 92/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1221 - accuracy: 0.7581
# Epoch 93/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1053 - accuracy: 0.8065
# Epoch 94/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1117 - accuracy: 0.7984
# Epoch 95/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1111 - accuracy: 0.7984
# Epoch 96/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1114 - accuracy: 0.7984
# Epoch 97/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1100 - accuracy: 0.8065
# Epoch 98/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1121 - accuracy: 0.7984
# Epoch 99/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1074 - accuracy: 0.7984
# Epoch 100/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1080 - accuracy: 0.7903
# Epoch 101/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1107 - accuracy: 0.7500
# Epoch 102/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1310 - accuracy: 0.6935
# Epoch 103/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1203 - accuracy: 0.7823
# Epoch 104/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1225 - accuracy: 0.7823
# Epoch 105/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1178 - accuracy: 0.7500
# Epoch 106/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1170 - accuracy: 0.7903
# Epoch 107/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1078 - accuracy: 0.7823
# Epoch 108/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1108 - accuracy: 0.7903
# Epoch 109/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1121 - accuracy: 0.7903
# Epoch 110/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1178 - accuracy: 0.7984
# Epoch 111/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1105 - accuracy: 0.7903
# Epoch 112/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1075 - accuracy: 0.8065
# Epoch 113/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1199 - accuracy: 0.7742
# Epoch 114/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1360 - accuracy: 0.7500
# Epoch 115/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1248 - accuracy: 0.7661
# Epoch 116/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1081 - accuracy: 0.7742
# Epoch 117/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1108 - accuracy: 0.7823
# Epoch 118/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1055 - accuracy: 0.7742
# Epoch 119/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1184 - accuracy: 0.7419
# Epoch 120/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1149 - accuracy: 0.7661
# Epoch 121/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1063 - accuracy: 0.7742
# Epoch 122/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1091 - accuracy: 0.7581
# Epoch 123/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1056 - accuracy: 0.7903
# Epoch 124/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1145 - accuracy: 0.7661
# Epoch 125/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1084 - accuracy: 0.8065
# Epoch 126/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1255 - accuracy: 0.7823
# Epoch 127/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1095 - accuracy: 0.7984
# Epoch 128/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1132 - accuracy: 0.7984
# Epoch 129/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1085 - accuracy: 0.7823
# Epoch 130/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1149 - accuracy: 0.7581
# Epoch 131/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1081 - accuracy: 0.7903
# Epoch 132/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1081 - accuracy: 0.7903
# Epoch 133/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1107 - accuracy: 0.7823
# Epoch 134/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1069 - accuracy: 0.7984
# Epoch 135/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1043 - accuracy: 0.8065
# Epoch 136/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1022 - accuracy: 0.8065
# Epoch 137/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1089 - accuracy: 0.7984
# Epoch 138/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1157 - accuracy: 0.7903
# Epoch 139/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1216 - accuracy: 0.7903
# Epoch 140/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1065 - accuracy: 0.7984
# Epoch 141/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1085 - accuracy: 0.7823
# Epoch 142/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1077 - accuracy: 0.7903
# Epoch 143/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1104 - accuracy: 0.7419
# Epoch 144/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1130 - accuracy: 0.7823
# Epoch 145/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1036 - accuracy: 0.7984
# Epoch 146/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1042 - accuracy: 0.7823
# Epoch 147/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1043 - accuracy: 0.7823
# Epoch 148/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1131 - accuracy: 0.7742
# Epoch 149/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1079 - accuracy: 0.7903
# Epoch 150/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1245 - accuracy: 0.7500
# Epoch 151/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1103 - accuracy: 0.8065
# Epoch 152/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1075 - accuracy: 0.7984
# Epoch 153/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1133 - accuracy: 0.7903
# Epoch 154/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1120 - accuracy: 0.7984
# Epoch 155/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1080 - accuracy: 0.7984
# Epoch 156/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1073 - accuracy: 0.8065
# Epoch 157/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1051 - accuracy: 0.7742
# Epoch 158/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1087 - accuracy: 0.7500
# Epoch 159/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1039 - accuracy: 0.8306
# Epoch 160/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1082 - accuracy: 0.7903
# Epoch 161/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1166 - accuracy: 0.7823
# Epoch 162/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1082 - accuracy: 0.7984
# Epoch 163/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1096 - accuracy: 0.7581
# Epoch 164/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1068 - accuracy: 0.7500
# Epoch 165/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1024 - accuracy: 0.8065
# Epoch 166/300
# 13/13 [==============================] - 0s 3ms/step - loss: 0.1070 - accuracy: 0.7903
# Epoch 167/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1125 - accuracy: 0.8065
# Epoch 168/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1082 - accuracy: 0.7903
# Epoch 169/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1042 - accuracy: 0.7903
# Epoch 170/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1101 - accuracy: 0.7984
# Epoch 171/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1224 - accuracy: 0.7661
# Epoch 172/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1225 - accuracy: 0.7419
# Epoch 173/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1134 - accuracy: 0.7823
# Epoch 174/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1099 - accuracy: 0.7742
# Epoch 175/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1052 - accuracy: 0.7903
# Epoch 176/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1091 - accuracy: 0.7742
# Epoch 177/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1113 - accuracy: 0.7419
# Epoch 178/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1062 - accuracy: 0.7903
# Epoch 179/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1072 - accuracy: 0.7903
# Epoch 180/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1132 - accuracy: 0.7661
# Epoch 181/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1231 - accuracy: 0.7500
# Epoch 182/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1087 - accuracy: 0.7903
# Epoch 183/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1213 - accuracy: 0.7903
# Epoch 184/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1170 - accuracy: 0.7823
# Epoch 185/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1223 - accuracy: 0.7742
# Epoch 186/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1241 - accuracy: 0.7661
# Epoch 187/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1093 - accuracy: 0.7903
# Epoch 188/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1067 - accuracy: 0.7984
# Epoch 189/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1064 - accuracy: 0.7984
# Epoch 190/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1064 - accuracy: 0.7823
# Epoch 191/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1056 - accuracy: 0.7984
# Epoch 192/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1056 - accuracy: 0.7984
# Epoch 193/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1053 - accuracy: 0.7742
# Epoch 194/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1057 - accuracy: 0.7581
# Epoch 195/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1050 - accuracy: 0.7984
# Epoch 196/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1049 - accuracy: 0.7984
# Epoch 197/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1050 - accuracy: 0.7984
# Epoch 198/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1053 - accuracy: 0.7984
# Epoch 199/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1050 - accuracy: 0.7984
# Epoch 200/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1052 - accuracy: 0.7984
# Epoch 201/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1049 - accuracy: 0.7984
# Epoch 202/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1051 - accuracy: 0.7984
# Epoch 203/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1050 - accuracy: 0.7984
# Epoch 204/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1052 - accuracy: 0.7984
# Epoch 205/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1050 - accuracy: 0.7984
# Epoch 206/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1051 - accuracy: 0.7984
# Epoch 207/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1054 - accuracy: 0.7581
# Epoch 208/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1050 - accuracy: 0.7903
# Epoch 209/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1064 - accuracy: 0.7419
# Epoch 210/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1044 - accuracy: 0.7984
# Epoch 211/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1059 - accuracy: 0.7984
# Epoch 212/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1057 - accuracy: 0.7984
# Epoch 213/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1055 - accuracy: 0.7984
# Epoch 214/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1057 - accuracy: 0.7984
# Epoch 215/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1054 - accuracy: 0.7984
# Epoch 216/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1050 - accuracy: 0.7984
# Epoch 217/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1052 - accuracy: 0.7984
# Epoch 218/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1051 - accuracy: 0.7984
# Epoch 219/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1050 - accuracy: 0.7984
# Epoch 220/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1049 - accuracy: 0.7984
# Epoch 221/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1049 - accuracy: 0.7984
# Epoch 222/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1049 - accuracy: 0.7984
# Epoch 223/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1054 - accuracy: 0.7823
# Epoch 224/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1052 - accuracy: 0.7984
# Epoch 225/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1051 - accuracy: 0.7984
# Epoch 226/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1050 - accuracy: 0.7984
# Epoch 227/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1050 - accuracy: 0.7984
# Epoch 228/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1059 - accuracy: 0.7581
# Epoch 229/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1057 - accuracy: 0.7661
# Epoch 230/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1056 - accuracy: 0.7984
# Epoch 231/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1051 - accuracy: 0.7984
# Epoch 232/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1057 - accuracy: 0.7984
# Epoch 233/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1049 - accuracy: 0.7984
# Epoch 234/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1056 - accuracy: 0.7984
# Epoch 235/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1049 - accuracy: 0.7984
# Epoch 236/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1050 - accuracy: 0.7984
# Epoch 237/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1049 - accuracy: 0.7984
# Epoch 238/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1049 - accuracy: 0.7984
# Epoch 239/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1050 - accuracy: 0.7984
# Epoch 240/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1048 - accuracy: 0.7984
# Epoch 241/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1049 - accuracy: 0.7984
# Epoch 242/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1053 - accuracy: 0.7984
# Epoch 243/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1049 - accuracy: 0.7984
# Epoch 244/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1052 - accuracy: 0.7984
# Epoch 245/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1052 - accuracy: 0.7984
# Epoch 246/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1051 - accuracy: 0.7984
# Epoch 247/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1050 - accuracy: 0.7984
# Epoch 248/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1061 - accuracy: 0.7984
# Epoch 249/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1055 - accuracy: 0.7984
# Epoch 250/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1051 - accuracy: 0.7984
# Epoch 251/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1049 - accuracy: 0.7984
# Epoch 252/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1048 - accuracy: 0.7984
# Epoch 253/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1050 - accuracy: 0.7984
# Epoch 254/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1053 - accuracy: 0.7984
# Epoch 255/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1050 - accuracy: 0.7984
# Epoch 256/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1054 - accuracy: 0.7984
# Epoch 257/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1050 - accuracy: 0.7984
# Epoch 258/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1056 - accuracy: 0.7984
# Epoch 259/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1051 - accuracy: 0.7984
# Epoch 260/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1055 - accuracy: 0.7984
# Epoch 261/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1050 - accuracy: 0.7984
# Epoch 262/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1049 - accuracy: 0.7984
# Epoch 263/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1054 - accuracy: 0.7984
# Epoch 264/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1052 - accuracy: 0.7984
# Epoch 265/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1056 - accuracy: 0.7419
# Epoch 266/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1053 - accuracy: 0.7661
# Epoch 267/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1048 - accuracy: 0.7984
# Epoch 268/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1051 - accuracy: 0.7984
# Epoch 269/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1081 - accuracy: 0.6855
# Epoch 270/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1046 - accuracy: 0.8145
# Epoch 271/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1048 - accuracy: 0.7984
# Epoch 272/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1055 - accuracy: 0.7984
# Epoch 273/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1053 - accuracy: 0.7823
# Epoch 274/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1051 - accuracy: 0.7500
# Epoch 275/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1052 - accuracy: 0.7984
# Epoch 276/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1048 - accuracy: 0.7984
# Epoch 277/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1053 - accuracy: 0.7984
# Epoch 278/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1048 - accuracy: 0.7984
# Epoch 279/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1050 - accuracy: 0.7984
# Epoch 280/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1051 - accuracy: 0.7984
# Epoch 281/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1056 - accuracy: 0.7984
# Epoch 282/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1050 - accuracy: 0.7984
# Epoch 283/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1060 - accuracy: 0.7984
# Epoch 284/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1049 - accuracy: 0.7984
# Epoch 285/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1052 - accuracy: 0.7984
# Epoch 286/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1045 - accuracy: 0.7984
# Epoch 287/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1054 - accuracy: 0.7419
# Epoch 288/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1054 - accuracy: 0.7419
# Epoch 289/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1055 - accuracy: 0.7984
# Epoch 290/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1050 - accuracy: 0.7823
# Epoch 291/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1051 - accuracy: 0.7823
# Epoch 292/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1051 - accuracy: 0.7903
# Epoch 293/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1070 - accuracy: 0.7984
# Epoch 294/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1056 - accuracy: 0.7984
# Epoch 295/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1050 - accuracy: 0.7984
# Epoch 296/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1050 - accuracy: 0.7984
# Epoch 297/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1052 - accuracy: 0.7984
# Epoch 298/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1045 - accuracy: 0.7984
# Epoch 299/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1048 - accuracy: 0.7581
# Epoch 300/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1052 - accuracy: 0.7823
