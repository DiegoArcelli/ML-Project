# %%
import pandas as pd, numpy as np
import matplotlib.pyplot as plt, seaborn as sns
# %matplotlib inline
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV
import pandas as pd
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score, f1_score, classification_report
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.model_selection import validation_curve
from sklearn import preprocessing

# %%
# Loading data
data = pd.read_csv('data/monks-1.train',header=None,sep=" ")
ts = pd.read_csv('data/monks-1.test',header=None,sep=" ")


data.drop(0,axis=1,inplace=True)
data.drop(8,axis=1,inplace=True)

# Create feature and target arrays
x = data.iloc[:, 1:]
y = data.iloc[:,0]

ts.drop(0,axis=1,inplace=True)
ts.drop(8,axis=1,inplace=True)

# Create feature and target arrays
xts = ts.iloc[:, 1:]
yts = ts.iloc[:,0]

# %%
rf = RandomForestClassifier(random_state=42, n_jobs=-1)
params = {
    'max_depth': [10,15],
    'min_samples_leaf': [5,10],
    'n_estimators': [10,15],
    'criterion' : ["gini"],
    'bootstrap' : ["True"]
}
# Instantiate the grid search model
grid_search = GridSearchCV(estimator=rf,
                           param_grid=params,
                           cv = 30,
                           n_jobs=-1, verbose=4, scoring="accuracy", return_train_score=True)
h = grid_search.fit(x, y)
# Out:
# Fitting 30 folds for each of 8 candidates, totalling 240 fits
# [CV 12/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=5, n_estimators=50;, score=(train=0.885, test=1.000) total time=   0.1s
# [CV 13/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=5, n_estimators=50;, score=(train=0.910, test=1.000) total time=   0.1s
# [CV 14/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=5, n_estimators=50;, score=(train=0.902, test=1.000) total time=   0.1s
# [CV 15/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=5, n_estimators=50;, score=(train=0.910, test=1.000) total time=   0.1s
# [CV 16/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=5, n_estimators=50;, score=(train=0.902, test=1.000) total time=   0.1s
# [CV 29/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=5, n_estimators=100;, score=(train=0.885, test=0.500) total time=   0.2s
# [CV 30/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=5, n_estimators=100;, score=(train=0.893, test=1.000) total time=   0.1s
# [CV 31/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=5, n_estimators=100;, score=(train=0.877, test=1.000) total time=   0.2s
# [CV 32/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=5, n_estimators=100;, score=(train=0.877, test=1.000) total time=   0.1s
# [CV 33/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=5, n_estimators=100;, score=(train=0.885, test=1.000) total time=   0.2s
# [CV 34/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=5, n_estimators=100;, score=(train=0.902, test=1.000) total time=   0.2s
# [CV 35/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=5, n_estimators=100;, score=(train=0.877, test=1.000) total time=   0.1s
# [CV 36/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=5, n_estimators=100;, score=(train=0.885, test=1.000) total time=   0.1s
# [CV 57/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=10, n_estimators=10;, score=(train=0.869, test=0.500) total time=   0.0s
# [CV 58/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=10, n_estimators=10;, score=(train=0.828, test=0.500) total time=   0.0s
# [CV 59/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=10, n_estimators=10;, score=(train=0.787, test=0.000) total time=   0.0s
# [CV 60/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=10, n_estimators=10;, score=(train=0.836, test=0.000) total time=   0.0s
# [CV 1/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=10, n_estimators=15;, score=(train=0.860, test=0.333) total time=   0.0s
# [CV 2/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=10, n_estimators=15;, score=(train=0.860, test=0.333) total time=   0.0s
# [CV 3/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=10, n_estimators=15;, score=(train=0.860, test=0.667) total time=   0.0s
# [CV 4/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=10, n_estimators=15;, score=(train=0.868, test=0.667) total time=   0.0s
# [CV 1/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=10, n_estimators=50;, score=(train=0.868, test=0.333) total time=   0.1s
# [CV 2/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=10, n_estimators=50;, score=(train=0.876, test=0.333) total time=   0.1s
# [CV 3/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=10, n_estimators=50;, score=(train=0.860, test=0.667) total time=   0.1s
# [CV 4/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=10, n_estimators=50;, score=(train=0.860, test=0.667) total time=   0.1s
# [CV 5/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=10, n_estimators=50;, score=(train=0.869, test=0.500) total time=   0.1s
# [CV 6/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=10, n_estimators=50;, score=(train=0.877, test=0.500) total time=   0.1s
# [CV 7/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=10, n_estimators=50;, score=(train=0.869, test=1.000) total time=   0.1s
# [CV 8/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=10, n_estimators=50;, score=(train=0.885, test=1.000) total time=   0.1s
# [CV 5/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=10, n_estimators=100;, score=(train=0.869, test=0.500) total time=   0.2s
# [CV 6/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=10, n_estimators=100;, score=(train=0.877, test=0.500) total time=   0.1s
# [CV 7/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=10, n_estimators=100;, score=(train=0.869, test=1.000) total time=   0.2s
# [CV 8/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=10, n_estimators=100;, score=(train=0.869, test=1.000) total time=   0.2s
# [CV 9/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=10, n_estimators=100;, score=(train=0.869, test=1.000) total time=   0.2s
# [CV 10/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=10, n_estimators=100;, score=(train=0.861, test=1.000) total time=   0.1s
# [CV 11/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=10, n_estimators=100;, score=(train=0.869, test=1.000) total time=   0.1s
# [CV 12/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=10, n_estimators=100;, score=(train=0.861, test=1.000) total time=   0.1s
# [CV 25/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=20, n_estimators=10;, score=(train=0.664, test=0.500) total time=   0.0s
# [CV 26/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=20, n_estimators=10;, score=(train=0.664, test=0.500) total time=   0.0s
# [CV 27/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=20, n_estimators=10;, score=(train=0.672, test=0.000) total time=   0.0s
# [CV 28/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=20, n_estimators=10;, score=(train=0.656, test=1.000) total time=   0.0s
# [CV 29/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=20, n_estimators=10;, score=(train=0.664, test=0.500) total time=   0.0s
# [CV 30/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=20, n_estimators=10;, score=(train=0.656, test=1.000) total time=   0.0s
# [CV 31/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=20, n_estimators=10;, score=(train=0.656, test=1.000) total time=   0.0s
# [CV 32/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=20, n_estimators=10;, score=(train=0.664, test=0.500) total time=   0.0s
# [CV 29/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=20, n_estimators=15;, score=(train=0.689, test=0.500) total time=   0.0s
# [CV 30/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=20, n_estimators=15;, score=(train=0.664, test=0.500) total time=   0.0s
# [CV 31/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=20, n_estimators=15;, score=(train=0.664, test=1.000) total time=   0.0s
# [CV 32/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=20, n_estimators=15;, score=(train=0.730, test=0.500) total time=   0.0s
# [CV 33/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=20, n_estimators=15;, score=(train=0.680, test=1.000) total time=   0.0s
# [CV 34/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=20, n_estimators=15;, score=(train=0.680, test=1.000) total time=   0.0s
# [CV 35/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=20, n_estimators=15;, score=(train=0.689, test=1.000) total time=   0.0s
# [CV 36/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=20, n_estimators=15;, score=(train=0.689, test=1.000) total time=   0.0s
# [CV 25/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=20, n_estimators=50;, score=(train=0.730, test=0.500) total time=   0.1s
# [CV 26/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=20, n_estimators=50;, score=(train=0.730, test=0.500) total time=   0.1s
# [CV 27/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=20, n_estimators=50;, score=(train=0.746, test=0.500) total time=   0.1s
# [CV 28/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=20, n_estimators=50;, score=(train=0.721, test=1.000) total time=   0.1s
# [CV 29/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=20, n_estimators=50;, score=(train=0.730, test=0.500) total time=   0.1s
# [CV 30/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=20, n_estimators=50;, score=(train=0.705, test=1.000) total time=   0.1s
# [CV 31/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=20, n_estimators=50;, score=(train=0.705, test=1.000) total time=   0.1s
# [CV 32/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=20, n_estimators=50;, score=(train=0.746, test=0.500) total time=   0.1s
# [CV 5/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=20, n_estimators=100;, score=(train=0.746, test=0.500) total time=   0.1s
# [CV 6/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=20, n_estimators=100;, score=(train=0.738, test=0.500) total time=   0.2s
# [CV 7/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=20, n_estimators=100;, score=(train=0.738, test=0.000) total time=   0.1s
# [CV 8/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=20, n_estimators=100;, score=(train=0.730, test=1.000) total time=   0.2s
# [CV 9/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=20, n_estimators=100;, score=(train=0.721, test=1.000) total time=   0.1s
# [CV 10/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=20, n_estimators=100;, score=(train=0.713, test=1.000) total time=   0.1s
# [CV 11/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=20, n_estimators=100;, score=(train=0.721, test=0.500) total time=   0.1s
# [CV 12/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=20, n_estimators=100;, score=(train=0.705, test=0.500) total time=   0.1s
# [CV 33/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=50, n_estimators=10;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 34/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=50, n_estimators=10;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 35/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=50, n_estimators=10;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 36/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=50, n_estimators=10;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 37/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=50, n_estimators=10;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 38/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=50, n_estimators=10;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 39/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=50, n_estimators=10;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 40/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=50, n_estimators=10;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 45/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=50, n_estimators=15;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 46/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=50, n_estimators=15;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 47/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=50, n_estimators=15;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 48/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=50, n_estimators=15;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 49/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=50, n_estimators=15;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 50/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=50, n_estimators=15;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 51/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=50, n_estimators=15;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 52/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=50, n_estimators=15;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 57/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=50, n_estimators=50;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 58/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=50, n_estimators=50;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 59/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=50, n_estimators=50;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 60/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=50, n_estimators=50;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 1/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=50, n_estimators=100;, score=(train=0.496, test=0.667) total time=   0.1s
# [CV 2/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=50, n_estimators=100;, score=(train=0.496, test=0.667) total time=   0.1s
# [CV 3/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=50, n_estimators=100;, score=(train=0.504, test=0.333) total time=   0.1s
# [CV 4/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=50, n_estimators=100;, score=(train=0.504, test=0.333) total time=   0.1s
# [CV 1/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=100, n_estimators=10;, score=(train=0.496, test=0.667) total time=   0.0s
# [CV 2/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=100, n_estimators=10;, score=(train=0.496, test=0.667) total time=   0.0s
# [CV 3/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=100, n_estimators=10;, score=(train=0.504, test=0.333) total time=   0.0s
# [CV 4/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=100, n_estimators=10;, score=(train=0.504, test=0.333) total time=   0.0s
# [CV 5/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=100, n_estimators=10;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 6/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=100, n_estimators=10;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 7/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=100, n_estimators=10;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 8/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=100, n_estimators=10;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 9/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=100, n_estimators=10;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 10/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=100, n_estimators=10;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 11/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=100, n_estimators=10;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 12/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=100, n_estimators=10;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 13/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=100, n_estimators=10;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 14/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=100, n_estimators=10;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 15/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=100, n_estimators=10;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 16/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=100, n_estimators=10;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 17/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=100, n_estimators=10;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 18/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=100, n_estimators=10;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 19/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=100, n_estimators=10;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 20/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=100, n_estimators=10;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 21/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=100, n_estimators=10;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 22/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=100, n_estimators=10;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 23/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=100, n_estimators=10;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 24/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=100, n_estimators=10;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 5/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=100, n_estimators=15;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 6/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=100, n_estimators=15;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 7/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=100, n_estimators=15;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 8/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=100, n_estimators=15;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 9/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=100, n_estimators=15;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 10/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=100, n_estimators=15;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 11/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=100, n_estimators=15;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 12/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=100, n_estimators=15;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 9/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=100, n_estimators=50;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 10/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=100, n_estimators=50;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 11/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=100, n_estimators=50;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 12/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=100, n_estimators=50;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 13/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=100, n_estimators=50;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 14/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=100, n_estimators=50;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 15/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=100, n_estimators=50;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 16/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=100, n_estimators=50;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 13/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=100, n_estimators=100;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 14/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=100, n_estimators=100;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 15/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=100, n_estimators=100;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 16/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=100, n_estimators=100;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 17/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=100, n_estimators=100;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 18/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=100, n_estimators=100;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 19/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=100, n_estimators=100;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 20/60] END bootstrap=False, criterion=entropy, max_depth=50, min_samples_leaf=100, n_estimators=100;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 33/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=5, n_estimators=10;, score=(train=0.951, test=1.000) total time=   0.0s
# [CV 34/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=5, n_estimators=10;, score=(train=0.910, test=1.000) total time=   0.0s
# [CV 35/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=5, n_estimators=10;, score=(train=0.902, test=1.000) total time=   0.0s
# [CV 36/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=5, n_estimators=10;, score=(train=0.902, test=1.000) total time=   0.0s
# [CV 37/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=5, n_estimators=10;, score=(train=0.893, test=1.000) total time=   0.0s
# [CV 38/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=5, n_estimators=10;, score=(train=0.877, test=1.000) total time=   0.0s
# [CV 39/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=5, n_estimators=10;, score=(train=0.926, test=1.000) total time=   0.0s
# [CV 40/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=5, n_estimators=10;, score=(train=0.934, test=1.000) total time=   0.0s
# [CV 29/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=5, n_estimators=15;, score=(train=0.902, test=0.500) total time=   0.0s
# [CV 30/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=5, n_estimators=15;, score=(train=0.926, test=1.000) total time=   0.0s
# [CV 31/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=5, n_estimators=15;, score=(train=0.910, test=1.000) total time=   0.0s
# [CV 32/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=5, n_estimators=15;, score=(train=0.902, test=1.000) total time=   0.0s
# [CV 33/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=5, n_estimators=15;, score=(train=0.918, test=1.000) total time=   0.0s
# [CV 34/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=5, n_estimators=15;, score=(train=0.934, test=1.000) total time=   0.0s
# [CV 35/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=5, n_estimators=15;, score=(train=0.902, test=1.000) total time=   0.0s
# [CV 36/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=5, n_estimators=15;, score=(train=0.902, test=1.000) total time=   0.0s
# [CV 25/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=5, n_estimators=50;, score=(train=0.910, test=0.500) total time=   0.1s
# [CV 26/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=5, n_estimators=50;, score=(train=0.902, test=1.000) total time=   0.1s
# [CV 27/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=5, n_estimators=50;, score=(train=0.910, test=1.000) total time=   0.1s
# [CV 28/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=5, n_estimators=50;, score=(train=0.902, test=0.500) total time=   0.1s
# [CV 29/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=5, n_estimators=50;, score=(train=0.902, test=0.500) total time=   0.1s
# [CV 30/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=5, n_estimators=50;, score=(train=0.885, test=1.000) total time=   0.1s
# [CV 31/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=5, n_estimators=50;, score=(train=0.893, test=1.000) total time=   0.1s
# [CV 32/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=5, n_estimators=50;, score=(train=0.910, test=1.000) total time=   0.1s
# [CV 29/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=5, n_estimators=100;, score=(train=0.885, test=0.500) total time=   0.2s
# [CV 30/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=5, n_estimators=100;, score=(train=0.893, test=1.000) total time=   0.2s
# [CV 31/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=5, n_estimators=100;, score=(train=0.877, test=1.000) total time=   0.2s
# [CV 32/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=5, n_estimators=100;, score=(train=0.877, test=1.000) total time=   0.1s
# [CV 33/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=5, n_estimators=100;, score=(train=0.885, test=1.000) total time=   0.1s
# [CV 34/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=5, n_estimators=100;, score=(train=0.902, test=1.000) total time=   0.2s
# [CV 35/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=5, n_estimators=100;, score=(train=0.877, test=1.000) total time=   0.2s
# [CV 36/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=5, n_estimators=100;, score=(train=0.885, test=1.000) total time=   0.1s
# [CV 57/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=10, n_estimators=10;, score=(train=0.869, test=0.500) total time=   0.0s
# [CV 58/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=10, n_estimators=10;, score=(train=0.828, test=0.500) total time=   0.0s
# [CV 59/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=10, n_estimators=10;, score=(train=0.787, test=0.000) total time=   0.0s
# [CV 60/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=10, n_estimators=10;, score=(train=0.836, test=0.000) total time=   0.0s
# [CV 1/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=10, n_estimators=15;, score=(train=0.860, test=0.333) total time=   0.0s
# [CV 2/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=10, n_estimators=15;, score=(train=0.860, test=0.333) total time=   0.0s
# [CV 3/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=10, n_estimators=15;, score=(train=0.860, test=0.667) total time=   0.0s
# [CV 4/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=10, n_estimators=15;, score=(train=0.868, test=0.667) total time=   0.0s
# [CV 1/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=10, n_estimators=50;, score=(train=0.868, test=0.333) total time=   0.1s
# [CV 2/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=10, n_estimators=50;, score=(train=0.876, test=0.333) total time=   0.1s
# [CV 3/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=10, n_estimators=50;, score=(train=0.860, test=0.667) total time=   0.1s
# [CV 4/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=10, n_estimators=50;, score=(train=0.860, test=0.667) total time=   0.1s
# [CV 5/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=10, n_estimators=50;, score=(train=0.869, test=0.500) total time=   0.1s
# [CV 6/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=10, n_estimators=50;, score=(train=0.877, test=0.500) total time=   0.1s
# [CV 7/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=10, n_estimators=50;, score=(train=0.869, test=1.000) total time=   0.1s
# [CV 8/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=10, n_estimators=50;, score=(train=0.885, test=1.000) total time=   0.1s
# [CV 13/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=10, n_estimators=100;, score=(train=0.852, test=1.000) total time=   0.2s
# [CV 14/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=10, n_estimators=100;, score=(train=0.861, test=1.000) total time=   0.2s
# [CV 15/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=10, n_estimators=100;, score=(train=0.844, test=1.000) total time=   0.2s
# [CV 16/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=10, n_estimators=100;, score=(train=0.852, test=1.000) total time=   0.2s
# [CV 17/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=10, n_estimators=100;, score=(train=0.844, test=1.000) total time=   0.1s
# [CV 18/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=10, n_estimators=100;, score=(train=0.861, test=0.500) total time=   0.1s
# [CV 19/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=10, n_estimators=100;, score=(train=0.844, test=1.000) total time=   0.1s
# [CV 20/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=10, n_estimators=100;, score=(train=0.844, test=1.000) total time=   0.1s
# [CV 49/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=20, n_estimators=10;, score=(train=0.664, test=1.000) total time=   0.0s
# [CV 50/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=20, n_estimators=10;, score=(train=0.656, test=0.500) total time=   0.0s
# [CV 51/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=20, n_estimators=10;, score=(train=0.656, test=0.500) total time=   0.0s
# [CV 52/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=20, n_estimators=10;, score=(train=0.713, test=0.000) total time=   0.0s
# [CV 53/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=20, n_estimators=10;, score=(train=0.656, test=0.500) total time=   0.0s
# [CV 54/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=20, n_estimators=10;, score=(train=0.730, test=0.500) total time=   0.0s
# [CV 55/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=20, n_estimators=10;, score=(train=0.738, test=0.500) total time=   0.0s
# [CV 56/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=20, n_estimators=10;, score=(train=0.680, test=0.500) total time=   0.0s
# [CV 45/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=20, n_estimators=15;, score=(train=0.730, test=1.000) total time=   0.0s
# [CV 46/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=20, n_estimators=15;, score=(train=0.738, test=0.500) total time=   0.0s
# [CV 47/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=20, n_estimators=15;, score=(train=0.705, test=0.500) total time=   0.0s
# [CV 48/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=20, n_estimators=15;, score=(train=0.705, test=0.000) total time=   0.0s
# [CV 49/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=20, n_estimators=15;, score=(train=0.721, test=1.000) total time=   0.0s
# [CV 50/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=20, n_estimators=15;, score=(train=0.730, test=0.500) total time=   0.0s
# [CV 51/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=20, n_estimators=15;, score=(train=0.730, test=0.500) total time=   0.0s
# [CV 52/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=20, n_estimators=15;, score=(train=0.721, test=0.000) total time=   0.0s
# [CV 49/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=20, n_estimators=50;, score=(train=0.730, test=1.000) total time=   0.1s
# [CV 50/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=20, n_estimators=50;, score=(train=0.730, test=0.500) total time=   0.1s
# [CV 51/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=20, n_estimators=50;, score=(train=0.730, test=0.500) total time=   0.1s
# [CV 52/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=20, n_estimators=50;, score=(train=0.746, test=0.000) total time=   0.1s
# [CV 53/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=20, n_estimators=50;, score=(train=0.730, test=0.500) total time=   0.1s
# [CV 54/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=20, n_estimators=50;, score=(train=0.738, test=0.500) total time=   0.1s
# [CV 55/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=20, n_estimators=50;, score=(train=0.738, test=0.500) total time=   0.1s
# [CV 56/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=20, n_estimators=50;, score=(train=0.746, test=0.500) total time=   0.1s
# [CV 53/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=20, n_estimators=100;, score=(train=0.738, test=0.500) total time=   0.1s
# [CV 54/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=20, n_estimators=100;, score=(train=0.746, test=1.000) total time=   0.2s
# [CV 55/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=20, n_estimators=100;, score=(train=0.738, test=0.500) total time=   0.2s
# [CV 56/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=20, n_estimators=100;, score=(train=0.754, test=0.500) total time=   0.2s
# [CV 57/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=20, n_estimators=100;, score=(train=0.754, test=0.500) total time=   0.1s
# [CV 58/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=20, n_estimators=100;, score=(train=0.730, test=0.500) total time=   0.2s
# [CV 59/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=20, n_estimators=100;, score=(train=0.754, test=0.000) total time=   0.1s
# [CV 60/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=20, n_estimators=100;, score=(train=0.746, test=0.500) total time=   0.1s
# [CV 53/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=50, n_estimators=15;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 54/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=50, n_estimators=15;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 55/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=50, n_estimators=15;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 56/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=50, n_estimators=15;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 57/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=50, n_estimators=15;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 58/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=50, n_estimators=15;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 59/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=50, n_estimators=15;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 60/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=50, n_estimators=15;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 41/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=50, n_estimators=50;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 42/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=50, n_estimators=50;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 43/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=50, n_estimators=50;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 44/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=50, n_estimators=50;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 45/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=50, n_estimators=50;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 46/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=50, n_estimators=50;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 47/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=50, n_estimators=50;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 48/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=50, n_estimators=50;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 13/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=50, n_estimators=100;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 14/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=50, n_estimators=100;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 15/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=50, n_estimators=100;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 16/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=50, n_estimators=100;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 17/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=50, n_estimators=100;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 18/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=50, n_estimators=100;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 19/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=50, n_estimators=100;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 20/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=50, n_estimators=100;, score=(train=0.500, test=0.500) total time=   0.2s
# [CV 21/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=100, n_estimators=15;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 22/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=100, n_estimators=15;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 23/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=100, n_estimators=15;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 24/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=100, n_estimators=15;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 25/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=100, n_estimators=15;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 26/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=100, n_estimators=15;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 27/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=100, n_estimators=15;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 28/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=100, n_estimators=15;, score=(train=0.500, test=0.500) total time=   0.0s
# [CV 17/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=100, n_estimators=50;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 18/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=100, n_estimators=50;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 19/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=100, n_estimators=50;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 20/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=100, n_estimators=50;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 21/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=100, n_estimators=50;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 22/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=100, n_estimators=50;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 23/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=100, n_estimators=50;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 24/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=100, n_estimators=50;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 5/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=100, n_estimators=100;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 6/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=100, n_estimators=100;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 7/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=100, n_estimators=100;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 8/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=100, n_estimators=100;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 9/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=100, n_estimators=100;, score=(train=0.500, test=0.500) total time=   0.2s
# [CV 10/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=100, n_estimators=100;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 11/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=100, n_estimators=100;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 12/60] END bootstrap=False, criterion=entropy, max_depth=100, min_samples_leaf=100, n_estimators=100;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 10/60] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=5, n_estimators=10;, score=(train=0.869, test=1.000) total time=   0.0s
# [CV 19/60] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=5, n_estimators=10;, score=(train=0.967, test=1.000) total time=   0.0s
# [CV 20/60] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=5, n_estimators=10;, score=(train=0.951, test=1.000) total time=   0.0s
# [CV 33/60] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=5, n_estimators=10;, score=(train=0.910, test=1.000) total time=   0.0s
# [CV 34/60] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=5, n_estimators=10;, score=(train=0.893, test=1.000) total time=   0.0s
# [CV 53/60] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=5, n_estimators=10;, score=(train=0.951, test=1.000) total time=   0.0s
# [CV 54/60] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=5, n_estimators=10;, score=(train=0.959, test=1.000) total time=   0.0s
# [CV 55/60] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=5, n_estimators=10;, score=(train=0.943, test=1.000) total time=   0.0s
# [CV 56/60] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=5, n_estimators=10;, score=(train=0.959, test=1.000) total time=   0.0s
# [CV 21/60] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=5, n_estimators=15;, score=(train=0.918, test=1.000) total time=   0.0s
# [CV 22/60] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=5, n_estimators=15;, score=(train=0.902, test=1.000) total time=   0.0s
# [CV 23/60] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=5, n_estimators=15;, score=(train=0.910, test=0.500) total time=   0.0s
# [CV 24/60] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=5, n_estimators=15;, score=(train=0.910, test=1.000) total time=   0.0s
# [CV 33/60] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=10, n_estimators=10;, score=(train=0.861, test=1.000) total time=   0.0s
# [CV 34/60] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=10, n_estimators=10;, score=(train=0.861, test=1.000) total time=   0.0s
# [CV 35/60] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=10, n_estimators=10;, score=(train=0.844, test=1.000) total time=   0.0s
# [CV 36/60] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=10, n_estimators=10;, score=(train=0.844, test=1.000) total time=   0.0s
# [CV 37/60] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=10, n_estimators=10;, score=(train=0.844, test=0.500) total time=   0.0s
# [CV 38/60] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=10, n_estimators=10;, score=(train=0.852, test=0.500) total time=   0.0s
# [CV 39/60] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=10, n_estimators=10;, score=(train=0.861, test=1.000) total time=   0.0s
# [CV 40/60] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=10, n_estimators=10;, score=(train=0.836, test=1.000) total time=   0.0s
# [CV 13/60] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=10, n_estimators=15;, score=(train=0.836, test=1.000) total time=   0.0s
# [CV 14/60] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=10, n_estimators=15;, score=(train=0.820, test=1.000) total time=   0.0s
# [CV 15/60] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=10, n_estimators=15;, score=(train=0.844, test=1.000) total time=   0.1s
# [CV 16/60] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=10, n_estimators=15;, score=(train=0.852, test=1.000) total time=   0.0s
# [CV 17/60] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=10, n_estimators=15;, score=(train=0.844, test=1.000) total time=   0.0s
# [CV 18/60] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=10, n_estimators=15;, score=(train=0.861, test=1.000) total time=   0.0s
# [CV 19/60] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=10, n_estimators=15;, score=(train=0.844, test=1.000) total time=   0.0s
# [CV 20/60] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=10, n_estimators=15;, score=(train=0.844, test=1.000) total time=   0.0s
# [CV 9/60] END bootstrap=True, criterion=gini, max_depth=30, min_samples_leaf=5, n_estimators=10;, score=(train=0.852, test=1.000) total time=   0.0s
# [CV 10/60] END bootstrap=True, criterion=gini, max_depth=30, min_samples_leaf=5, n_estimators=10;, score=(train=0.869, test=1.000) total time=   0.0s
# [CV 11/60] END bootstrap=True, criterion=gini, max_depth=30, min_samples_leaf=5, n_estimators=10;, score=(train=0.877, test=1.000) total time=   0.0s
# ...
# [CV 39/60] END bootstrap=True, criterion=gini, max_depth=30, min_samples_leaf=5, n_estimators=15;, score=(train=0.877, test=1.000) total time=   0.0s
# [CV 40/60] END bootstrap=True, criterion=gini, max_depth=30, min_samples_leaf=5, n_estimators=15;, score=(train=0.885, test=1.000) total time=   0.0s
# [CV 41/60] END bootstrap=True, criterion=gini, max_depth=30, min_samples_leaf=5, n_estimators=15;, score=(train=0.852, test=1.000) total time=   0.0s
# [CV 42/60] END bootstrap=True, criterion=gini, max_depth=30, min_samples_leaf=5, n_estimators=15;, score=(train=0.869, test=1.000) total time=   0.0s
# [CV 43/60] END bootstrap=True, criterion=gini, max_depth=30, min_samples_leaf=5, n_estimators=15;, score=(train=0.902, test=1.000) total time=   0.0s
# [CV 44/60] END bootstrap=True, criterion=gini, max_depth=30, min_samples_leaf=5, n_estimators=15;, score=(train=0.943, test=1.000) total time=   0.0s
# [CV 13/60] END bootstrap=True, criterion=gini, max_depth=30, min_samples_leaf=10, n_estimators=15;, score=(train=0.836, test=1.000) total time=   0.0s
# [CV 14/60] END bootstrap=True, criterion=gini, max_depth=30, min_samples_leaf=10, n_estimators=15;, score=(train=0.820, test=1.000) total time=   0.0s
# [CV 15/60] END bootstrap=True, criterion=gini, max_depth=30, min_samples_leaf=10, n_estimators=15;, score=(train=0.844, test=1.000) total time=   0.0s
# [CV 16/60] END bootstrap=True, criterion=gini, max_depth=30, min_samples_leaf=10, n_estimators=15;, score=(train=0.852, test=1.000) total time=   0.0s
# [CV 17/60] END bootstrap=True, criterion=gini, max_depth=30, min_samples_leaf=10, n_estimators=15;, score=(train=0.844, test=1.000) total time=   0.0s
# [CV 18/60] END bootstrap=True, criterion=gini, max_depth=30, min_samples_leaf=10, n_estimators=15;, score=(train=0.861, test=1.000) total time=   0.0s
# [CV 21/60] END bootstrap=True, criterion=gini, max_depth=30, min_samples_leaf=10, n_estimators=15;, score=(train=0.844, test=1.000) total time=   0.0s
# [CV 25/60] END bootstrap=True, criterion=gini, max_depth=30, min_samples_leaf=10, n_estimators=15;, score=(train=0.836, test=1.000) total time=   0.0s
# [CV 31/60] END bootstrap=True, criterion=gini, max_depth=30, min_samples_leaf=10, n_estimators=15;, score=(train=0.852, test=0.500) total time=   0.1s
# [CV 55/60] END bootstrap=True, criterion=gini, max_depth=30, min_samples_leaf=10, n_estimators=15;, score=(train=0.762, test=0.500) total time=   0.0s
# [CV 59/60] END bootstrap=True, criterion=gini, max_depth=30, min_samples_leaf=10, n_estimators=15;, score=(train=0.836, test=0.500) total time=   0.0s
# [CV 6/30] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=5, n_estimators=10;, score=(train=0.900, test=1.000) total time=   0.0s
# [CV 13/30] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=5, n_estimators=10;, score=(train=0.892, test=0.500) total time=   0.0s
# [CV 25/30] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=5, n_estimators=10;, score=(train=0.892, test=0.750) total time=   0.0s
# [CV 26/30] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=5, n_estimators=10;, score=(train=0.900, test=0.750) total time=   0.0s
# [CV 9/30] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=5, n_estimators=15;, score=(train=0.925, test=0.750) total time=   0.0s
# [CV 10/30] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=5, n_estimators=15;, score=(train=0.900, test=1.000) total time=   0.0s
# [CV 1/30] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=10, n_estimators=10;, score=(train=0.891, test=0.400) total time=   0.0s
# [CV 2/30] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=10, n_estimators=10;, score=(train=0.874, test=0.400) total time=   0.0s
# [CV 3/30] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=10, n_estimators=10;, score=(train=0.874, test=0.600) total time=   0.0s
# [CV 4/30] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=10, n_estimators=10;, score=(train=0.866, test=1.000) total time=   0.0s
# [CV 3/30] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=10, n_estimators=15;, score=(train=0.857, test=0.600) total time=   0.0s
# [CV 4/30] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=10, n_estimators=15;, score=(train=0.866, test=1.000) total time=   0.0s
# [CV 5/30] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=10, n_estimators=15;, score=(train=0.858, test=1.000) total time=   0.0s
# [CV 6/30] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=10, n_estimators=15;, score=(train=0.833, test=1.000) total time=   0.0s
# [CV 17/30] END bootstrap=True, criterion=gini, max_depth=30, min_samples_leaf=5, n_estimators=10;, score=(train=0.883, test=1.000) total time=   0.0s
# [CV 18/30] END bootstrap=True, criterion=gini, max_depth=30, min_samples_leaf=5, n_estimators=10;, score=(train=0.892, test=1.000) total time=   0.0s
# [CV 19/30] END bootstrap=True, criterion=gini, max_depth=30, min_samples_leaf=5, n_estimators=10;, score=(train=0.892, test=1.000) total time=   0.0s
# [CV 20/30] END bootstrap=True, criterion=gini, max_depth=30, min_samples_leaf=5, n_estimators=10;, score=(train=0.900, test=1.000) total time=   0.0s
# [CV 21/30] END bootstrap=True, criterion=gini, max_depth=30, min_samples_leaf=5, n_estimators=10;, score=(train=0.900, test=1.000) total time=   0.0s
# [CV 22/30] END bootstrap=True, criterion=gini, max_depth=30, min_samples_leaf=5, n_estimators=10;, score=(train=0.917, test=0.750) total time=   0.0s
# [CV 23/30] END bootstrap=True, criterion=gini, max_depth=30, min_samples_leaf=5, n_estimators=10;, score=(train=0.917, test=0.750) total time=   0.0s
# [CV 24/30] END bootstrap=True, criterion=gini, max_depth=30, min_samples_leaf=5, n_estimators=10;, score=(train=0.908, test=0.500) total time=   0.0s
# [CV 5/30] END bootstrap=True, criterion=gini, max_depth=30, min_samples_leaf=10, n_estimators=10;, score=(train=0.842, test=1.000) total time=   0.1s
# [CV 6/30] END bootstrap=True, criterion=gini, max_depth=30, min_samples_leaf=10, n_estimators=10;, score=(train=0.842, test=1.000) total time=   0.0s
# [CV 7/30] END bootstrap=True, criterion=gini, max_depth=30, min_samples_leaf=10, n_estimators=10;, score=(train=0.850, test=1.000) total time=   0.0s
# [CV 8/30] END bootstrap=True, criterion=gini, max_depth=30, min_samples_leaf=10, n_estimators=10;, score=(train=0.808, test=0.750) total time=   0.0s
# [CV 9/30] END bootstrap=True, criterion=gini, max_depth=30, min_samples_leaf=10, n_estimators=10;, score=(train=0.867, test=0.750) total time=   0.0s
# [CV 10/30] END bootstrap=True, criterion=gini, max_depth=30, min_samples_leaf=10, n_estimators=10;, score=(train=0.850, test=1.000) total time=   0.0s
# [CV 11/30] END bootstrap=True, criterion=gini, max_depth=30, min_samples_leaf=10, n_estimators=10;, score=(train=0.842, test=0.500) total time=   0.0s
# [CV 12/30] END bootstrap=True, criterion=gini, max_depth=30, min_samples_leaf=10, n_estimators=10;, score=(train=0.850, test=0.750) total time=   0.0s
# [CV 14/30] END bootstrap=True, criterion=gini, max_depth=7, min_samples_leaf=5, n_estimators=7;, score=(train=0.833, test=0.500) total time=   0.0s
# [CV 27/30] END bootstrap=True, criterion=gini, max_depth=7, min_samples_leaf=5, n_estimators=7;, score=(train=0.817, test=1.000) total time=   0.0s
# [CV 28/30] END bootstrap=True, criterion=gini, max_depth=7, min_samples_leaf=5, n_estimators=7;, score=(train=0.833, test=0.750) total time=   0.0s
# [CV 9/30] END bootstrap=True, criterion=gini, max_depth=7, min_samples_leaf=5, n_estimators=10;, score=(train=0.933, test=1.000) total time=   0.0s
# [CV 10/30] END bootstrap=True, criterion=gini, max_depth=7, min_samples_leaf=5, n_estimators=10;, score=(train=0.892, test=1.000) total time=   0.0s
# [CV 5/30] END bootstrap=True, criterion=gini, max_depth=7, min_samples_leaf=5, n_estimators=13;, score=(train=0.858, test=1.000) total time=   0.0s
# [CV 6/30] END bootstrap=True, criterion=gini, max_depth=7, min_samples_leaf=5, n_estimators=13;, score=(train=0.883, test=1.000) total time=   0.0s
# [CV 7/30] END bootstrap=True, criterion=gini, max_depth=7, min_samples_leaf=5, n_estimators=13;, score=(train=0.867, test=0.750) total time=   0.0s
# [CV 8/30] END bootstrap=True, criterion=gini, max_depth=7, min_samples_leaf=5, n_estimators=13;, score=(train=0.867, test=1.000) total time=   0.0s
# [CV 3/30] END bootstrap=True, criterion=gini, max_depth=7, min_samples_leaf=7, n_estimators=7;, score=(train=0.815, test=0.600) total time=   0.0s
# [CV 4/30] END bootstrap=True, criterion=gini, max_depth=7, min_samples_leaf=7, n_estimators=7;, score=(train=0.807, test=0.800) total time=   0.0s
# [CV 5/30] END bootstrap=True, criterion=gini, max_depth=7, min_samples_leaf=7, n_estimators=7;, score=(train=0.833, test=1.000) total time=   0.1s
# [CV 6/30] END bootstrap=True, criterion=gini, max_depth=7, min_samples_leaf=7, n_estimators=7;, score=(train=0.792, test=1.000) total time=   0.0s
# [CV 11/30] END bootstrap=True, criterion=gini, max_depth=7, min_samples_leaf=7, n_estimators=13;, score=(train=0.833, test=0.500) total time=   0.0s
# [CV 12/30] END bootstrap=True, criterion=gini, max_depth=7, min_samples_leaf=7, n_estimators=13;, score=(train=0.858, test=0.750) total time=   0.0s
# [CV 13/30] END bootstrap=True, criterion=gini, max_depth=7, min_samples_leaf=7, n_estimators=13;, score=(train=0.850, test=0.500) total time=   0.0s
# [CV 14/30] END bootstrap=True, criterion=gini, max_depth=7, min_samples_leaf=7, n_estimators=13;, score=(train=0.825, test=0.500) total time=   0.0s
# [CV 15/30] END bootstrap=True, criterion=gini, max_depth=7, min_samples_leaf=7, n_estimators=13;, score=(train=0.833, test=0.750) total time=   0.0s
# [CV 16/30] END bootstrap=True, criterion=gini, max_depth=7, min_samples_leaf=7, n_estimators=13;, score=(train=0.817, test=1.000) total time=   0.0s
# [CV 17/30] END bootstrap=True, criterion=gini, max_depth=7, min_samples_leaf=7, n_estimators=13;, score=(train=0.850, test=1.000) total time=   0.0s
# [CV 18/30] END bootstrap=True, criterion=gini, max_depth=7, min_samples_leaf=7, n_estimators=13;, score=(train=0.850, test=1.000) total time=   0.0s
# [CV 21/30] END bootstrap=True, criterion=gini, max_depth=7, min_samples_leaf=10, n_estimators=7;, score=(train=0.808, test=1.000) total time=   0.0s
# [CV 22/30] END bootstrap=True, criterion=gini, max_depth=7, min_samples_leaf=10, n_estimators=7;, score=(train=0.825, test=0.750) total time=   0.0s
# [CV 23/30] END bootstrap=True, criterion=gini, max_depth=7, min_samples_leaf=10, n_estimators=7;, score=(train=0.808, test=0.750) total time=   0.0s
# [CV 24/30] END bootstrap=True, criterion=gini, max_depth=7, min_samples_leaf=10, n_estimators=7;, score=(train=0.800, test=0.000) total time=   0.0s
# [CV 25/30] END bootstrap=True, criterion=gini, max_depth=7, min_samples_leaf=10, n_estimators=7;, score=(train=0.775, test=0.750) total time=   0.0s
# [CV 26/30] END bootstrap=True, criterion=gini, max_depth=7, min_samples_leaf=10, n_estimators=7;, score=(train=0.742, test=0.500) total time=   0.0s
# [CV 27/30] END bootstrap=True, criterion=gini, max_depth=7, min_samples_leaf=10, n_estimators=7;, score=(train=0.775, test=1.000) total time=   0.0s
# [CV 28/30] END bootstrap=True, criterion=gini, max_depth=7, min_samples_leaf=10, n_estimators=7;, score=(train=0.758, test=0.750) total time=   0.0s
# [CV 17/30] END bootstrap=True, criterion=gini, max_depth=7, min_samples_leaf=10, n_estimators=13;, score=(train=0.858, test=1.000) total time=   0.1s
# [CV 18/30] END bootstrap=True, criterion=gini, max_depth=7, min_samples_leaf=10, n_estimators=13;, score=(train=0.842, test=1.000) total time=   0.0s
# [CV 19/30] END bootstrap=True, criterion=gini, max_depth=7, min_samples_leaf=10, n_estimators=13;, score=(train=0.842, test=1.000) total time=   0.0s
# [CV 20/30] END bootstrap=True, criterion=gini, max_depth=7, min_samples_leaf=10, n_estimators=13;, score=(train=0.858, test=1.000) total time=   0.0s
# [CV 21/30] END bootstrap=True, criterion=gini, max_depth=7, min_samples_leaf=10, n_estimators=13;, score=(train=0.833, test=1.000) total time=   0.0s
# [CV 22/30] END bootstrap=True, criterion=gini, max_depth=7, min_samples_leaf=10, n_estimators=13;, score=(train=0.867, test=0.750) total time=   0.0s
# [CV 23/30] END bootstrap=True, criterion=gini, max_depth=7, min_samples_leaf=10, n_estimators=13;, score=(train=0.883, test=1.000) total time=   0.0s
# [CV 24/30] END bootstrap=True, criterion=gini, max_depth=7, min_samples_leaf=10, n_estimators=13;, score=(train=0.875, test=0.000) total time=   0.1s
# [CV 23/30] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=5, n_estimators=13;, score=(train=0.925, test=0.750) total time=   0.0s
# [CV 24/30] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=5, n_estimators=13;, score=(train=0.892, test=0.500) total time=   0.0s
# [CV 25/30] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=5, n_estimators=13;, score=(train=0.900, test=0.750) total time=   0.0s
# [CV 26/30] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=5, n_estimators=13;, score=(train=0.908, test=1.000) total time=   0.0s
# [CV 27/30] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=5, n_estimators=13;, score=(train=0.908, test=1.000) total time=   0.0s
# [CV 28/30] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=5, n_estimators=13;, score=(train=0.908, test=0.750) total time=   0.1s
# [CV 29/30] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=5, n_estimators=13;, score=(train=0.900, test=0.500) total time=   0.0s
# [CV 30/30] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=5, n_estimators=13;, score=(train=0.900, test=0.750) total time=   0.0s
# [CV 21/30] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=7, n_estimators=13;, score=(train=0.883, test=1.000) total time=   0.0s
# [CV 22/30] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=7, n_estimators=13;, score=(train=0.867, test=0.750) total time=   0.0s
# [CV 23/30] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=7, n_estimators=13;, score=(train=0.908, test=1.000) total time=   0.0s
# [CV 24/30] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=7, n_estimators=13;, score=(train=0.808, test=0.750) total time=   0.0s
# [CV 25/30] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=7, n_estimators=13;, score=(train=0.875, test=1.000) total time=   0.0s
# [CV 26/30] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=7, n_estimators=13;, score=(train=0.875, test=0.750) total time=   0.0s
# [CV 27/30] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=7, n_estimators=13;, score=(train=0.850, test=1.000) total time=   0.0s
# [CV 28/30] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=7, n_estimators=13;, score=(train=0.850, test=0.250) total time=   0.0s
# [CV 9/30] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=10, n_estimators=10;, score=(train=0.867, test=0.750) total time=   0.0s
# [CV 10/30] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=10, n_estimators=10;, score=(train=0.850, test=1.000) total time=   0.1s
# [CV 11/30] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=10, n_estimators=10;, score=(train=0.842, test=0.500) total time=   0.0s
# [CV 12/30] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=10, n_estimators=10;, score=(train=0.850, test=0.750) total time=   0.0s
# [CV 13/30] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=10, n_estimators=10;, score=(train=0.825, test=0.750) total time=   0.0s
# [CV 14/30] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=10, n_estimators=10;, score=(train=0.867, test=0.750) total time=   0.0s

# %%
print('Best Score: %.3f' % grid_search.best_score_)
# Out:
# Best Score: 0.827

# %%
grid_search.best_params_
# Out:
# {'bootstrap': 'True',
#  'criterion': 'gini',
#  'max_depth': 10,
#  'min_samples_leaf': 5,
#  'n_estimators': 10}

# %%
validation_scores = h.cv_results_['mean_test_score']
train_scores = h.cv_results_['mean_train_score'] 
plt.plot(validation_scores, label='validation score')
plt.plot(train_scores, label='train score')
plt.legend(loc='best')
plt.show()

# %%
y_pred = grid_search.predict(xts)
import warnings
warnings.filterwarnings('ignore')  

print("Accuracy score:", accuracy_score(yts, y_pred))
# Out:
# Accuracy score: 0.9050925925925926

# %%
print(classification_report(yts, y_pred))
print(confusion_matrix(yts, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.92      0.91       216
#            1       0.92      0.89      0.90       216
#
#     accuracy                           0.91       432
#    macro avg       0.91      0.91      0.91       432
# weighted avg       0.91      0.91      0.91       432
#
# [[199  17]
#  [ 24 192]]
