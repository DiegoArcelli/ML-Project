# %%
# Import necessary modules,
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets
from sklearn.preprocessing import normalize
from sklearn.model_selection import learning_curve
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score, f1_score, classification_report
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.model_selection import validation_curve

# %%
# Loading data
monk1_train = pd.read_csv('data/monks-1.train',header=None,sep=" ")
monk1_test = pd.read_csv('data/monks-1.test',header=None,sep=" ")
monk2_train = pd.read_csv('data/monks-2.train',header=None,sep=" ")
monk2_test = pd.read_csv('data/monks-2.test',header=None,sep=" ")
monk3_train = pd.read_csv('data/monks-3.train',header=None,sep=" ")
monk3_test = pd.read_csv('data/monks-3.test',header=None,sep=" ")
ml_cup22_train = pd.read_csv('data/ML-CUP22-TR.csv', header=None)
ml_cup22_test = pd.read_csv('data/ML-CUP22-TS.csv', header=None)

# %%
train1 = monk1_train.drop(columns=0)
columns = ['class', 'a1', 'a2', 'a3', 'a4', 'a4', 'a6', 'id']
train1.columns = columns
test1 = monk1_test.drop(columns=0)
columns = ['class', 'a1', 'a2', 'a3', 'a4', 'a4', 'a6', 'id']
test1.columns = columns
train2 = monk2_train.drop(columns=0)
columns = ['class', 'a1', 'a2', 'a3', 'a4', 'a4', 'a6', 'id']
train2.columns = columns
test2 = monk2_test.drop(columns=0)
columns = ['class', 'a1', 'a2', 'a3', 'a4', 'a4', 'a6', 'id']
test2.columns = columns
train3 = monk3_train.drop(columns=0)
columns = ['class', 'a1', 'a2', 'a3', 'a4', 'a4', 'a6', 'id']
train3.columns = columns
test3 = monk3_test.drop(columns=0)
columns = ['class', 'a1', 'a2', 'a3', 'a4', 'a4', 'a6', 'id']
test3.columns = columns

# %%
# Splitting the train set in X and y
X_train1 = train1.copy()
y_train1 = X_train1['class']
X_train1 = X_train1.drop(columns='id')
X_train1 = X_train1.drop(columns='class')
X_train1 = X_train1.values
# Splitting the test set in X and y
X_test1 = test1.copy()
y_test1 = X_test1['class']
X_test1 = X_test1.drop(columns='id')
X_test1 = X_test1.drop(columns='class')
X_test1 = X_test1.values

# %%
# Splitting the train set in X and y
X_train2 = train2.copy()
y_train2 = X_train2['class']
X_train2 = X_train2.drop(columns='id')
X_train2 = X_train2.drop(columns='class')
X_train2 = X_train2.values
# Splitting the test set in X and y
X_test2 = test2.copy()
y_test2 = X_test2['class']
X_test2 = X_test2.drop(columns='id')
X_test2 = X_test2.drop(columns='class')
X_test2 = X_test2.values

# %%
# Splitting the train set in X and y
X_train3 = train3.copy()
y_train3 = X_train3['class']
X_train3 = X_train3.drop(columns='id')
X_train3 = X_train3.drop(columns='class')
X_train3 = X_train3.values
# Splitting the test set in X and y
X_test3 = test3.copy()
y_test3 = X_test3['class']
X_test3 = X_test3.drop(columns='id')
X_test3 = X_test3.drop(columns='class')
X_test3 = X_test3.values

# %%
pipeline = make_pipeline(KNeighborsClassifier())
param_grid = [{
    'kneighborsclassifier__n_neighbors': [4,6,8], # lower VL error increase
    'kneighborsclassifier__p': [1],
    'kneighborsclassifier__weights': ['distance'],
    'kneighborsclassifier__algorithm': ['auto'],
    'kneighborsclassifier__metric': ['euclidean','manhattan','cityblock'],
    }]

# %% [markdown]
# # Parameters config

# %%
# Create a grid search instance
gs = GridSearchCV(pipeline, param_grid = param_grid,
    scoring='accuracy',
    refit=True,
    cv=60,
    verbose=4,
    n_jobs=1,
    return_train_score=True)

# %%
# Run fit over all the models (combinations of hyperparameters)
h = gs.fit(X_train2, y_train2)
# Out:
# Fitting 60 folds for each of 9 candidates, totalling 540 fits
# [CV 1/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 2/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 3/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 4/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 5/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 6/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 7/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 8/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 9/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 10/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 11/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 12/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 13/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.000) total time=   0.0s
# [CV 14/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 15/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 16/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 17/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 18/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 19/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.000) total time=   0.0s
# [CV 20/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 21/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 22/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 23/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 24/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 25/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 26/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 27/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 28/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 29/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 30/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 31/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 32/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 33/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 34/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 35/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 36/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 37/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 38/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 39/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 40/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 41/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 42/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 43/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 44/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 45/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 46/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 47/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 48/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 49/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 50/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.500) total time=   0.0s
# [CV 51/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.500) total time=   0.0s
# [CV 52/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 53/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 54/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 55/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.500) total time=   0.0s
# [CV 56/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 57/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 58/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.500) total time=   0.0s
# [CV 59/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.000) total time=   0.0s
# [CV 60/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 1/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 2/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 3/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 4/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 5/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 6/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 7/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 8/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 9/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 10/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 11/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 12/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 13/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 14/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 15/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 16/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.000) total time=   0.0s
# [CV 17/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 18/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 19/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.000) total time=   0.0s
# [CV 20/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 21/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 22/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 23/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 24/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 25/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 26/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 27/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 28/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 29/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 30/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 31/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 32/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 33/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 34/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 35/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 36/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 37/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 38/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 39/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 40/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 41/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 42/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 43/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 44/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 45/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 46/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 47/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 48/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 49/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 50/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.500) total time=   0.0s
# [CV 51/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.500) total time=   0.0s
# [CV 52/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 53/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.500) total time=   0.0s
# [CV 54/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 55/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.500) total time=   0.0s
# [CV 56/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 57/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 58/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.500) total time=   0.0s
# [CV 59/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 60/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 1/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 2/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 3/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 4/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 5/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 6/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 7/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 8/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 9/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 10/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 11/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 12/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 13/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 14/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 15/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 16/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.000) total time=   0.0s
# [CV 17/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 18/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 19/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 20/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 21/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 22/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 23/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 24/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 25/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 26/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 27/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 28/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 29/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 30/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 31/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 32/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 33/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 34/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 35/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 36/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 37/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 38/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 39/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 40/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 41/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 42/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 43/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 44/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 45/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 46/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 47/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 48/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 49/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 50/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.500) total time=   0.0s
# [CV 51/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.500) total time=   0.0s
# [CV 52/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 53/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.500) total time=   0.0s
# [CV 54/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 55/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.000) total time=   0.0s
# [CV 56/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 57/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 58/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.500) total time=   0.0s
# [CV 59/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 60/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 1/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 2/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 3/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 4/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 5/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 6/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 7/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 8/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 9/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 10/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 11/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 12/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=4, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# ...
# [CV 57/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 58/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.500) total time=   0.0s
# [CV 59/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.500) total time=   0.0s
# [CV 60/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=6, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 1/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 2/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 3/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 4/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 5/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 6/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 7/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 8/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 9/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 10/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 11/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 12/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 13/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 14/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 15/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 16/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.000) total time=   0.0s
# [CV 17/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 18/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 19/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.000) total time=   0.0s
# [CV 20/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 21/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 22/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 23/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 24/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 25/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 26/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 27/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 28/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 29/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 30/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 31/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 32/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 33/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 34/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 35/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 36/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 37/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 38/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 39/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 40/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 41/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 42/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 43/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 44/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 45/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 46/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 47/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.333) total time=   0.0s
# [CV 48/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 49/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 50/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.500) total time=   0.0s
# [CV 51/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.500) total time=   0.0s
# [CV 52/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 53/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.500) total time=   0.0s
# [CV 54/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 55/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.000) total time=   0.0s
# [CV 56/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 57/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 58/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=0.500) total time=   0.0s
# [CV 59/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 60/60] END kneighborsclassifier__algorithm=auto, kneighborsclassifier__metric=cityblock, kneighborsclassifier__n_neighbors=8, kneighborsclassifier__p=1, kneighborsclassifier__weights=distance;, score=(train=1.000, test=1.000) total time=   0.0s

# %%
print('Best Score: %.3f' % gs.best_score_, 'Best Parameters: ', gs.best_params_)
# Out:
# Best Score: 0.658 Best Parameters:  {'kneighborsclassifier__algorithm': 'auto', 'kneighborsclassifier__metric': 'euclidean', 'kneighborsclassifier__n_neighbors': 6, 'kneighborsclassifier__p': 1, 'kneighborsclassifier__weights': 'distance'}

# %%
# k=6,p=1,auto,euclidian, distance -> overfit

# %%
validation_scores = h.cv_results_['mean_test_score']
train_scores = h.cv_results_['mean_train_score'] 
plt.plot(validation_scores, label='validation score')
plt.plot(train_scores, label='train score')
plt.legend(loc='best')
plt.show()

# %%
y_pred2 = gs.predict(X_test2)
import warnings
warnings.filterwarnings('ignore')  

print("Accuracy score:", accuracy_score(y_test2, y_pred2))
# Out:
# Accuracy score: 0.7777777777777778

# %%
print(classification_report(y_test2, y_pred2))
print(confusion_matrix(y_test2, y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.85      0.84       290
#            1       0.67      0.63      0.65       142
#
#     accuracy                           0.78       432
#    macro avg       0.75      0.74      0.74       432
# weighted avg       0.77      0.78      0.78       432
#
# [[246  44]
#  [ 52  90]]
